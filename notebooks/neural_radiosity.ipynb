# %%
import torch
import plotly.express as px
import numpy as np

##
# Sampling
def generate_random_spheres(n):
    loc = torch.randn((n, 3))
    radius = torch.rand((n, 1))
    base_color = torch.rand((n, 3)) * 0.5 + 0.25
    return torch.concat((loc, radius, base_color), dim=1)

def uniform_sample_directions(n):
    theta = 2 * torch.pi * torch.rand(n)
    phi = torch.acos(1 - 2 * torch.rand(n))
    
    x = torch.sin(phi) * torch.cos(theta)
    y = torch.sin(phi) * torch.sin(theta)
    z = torch.cos(phi)

    sample = torch.stack([x, y, z], dim=1)
    return sample

def uniform_sample_on_spheres(spheres, n):
    centers = spheres[:, 0:3]  # (N, 3)
    radii = spheres[:, 3:4]  # (N, 1)
    
    areas = 4 * torch.pi * radii ** 2
    total_area = areas.sum()
    
    probabilities = areas / total_area
    sphere_indices = torch.multinomial(probabilities.squeeze(1), n, replacement=True)
    
    sampled_radii = radii[sphere_indices]
    sampled_centers = centers[sphere_indices]

    samples = sampled_radii * uniform_sample_directions(n) + sampled_centers
    return samples, spheres[sphere_indices]

##
# Orthonormal basis
def dot(vec1, vec2):
    return (vec1 * vec2).sum(dim=-1, keepdim=True)

def norm(vec):
    return torch.norm(vec, p=2, dim=-1, keepdim=True)

def to_world(w, normals):
    # https://graphics.pixar.com/library/OrthonormalB/paper.pdf
    x, y, z = normals[:, 0:1], normals[:, 1:2], normals[:, 2:3]
    sign = torch.where(z >= 0.0, 1.0, -1.0)
    a = -1.0 / (sign + z)
    b = x * y * a

    b1 = torch.concat((1.0 + sign * x * x * a, sign * b, -sign * x), dim=1)
    b2 = torch.concat((b, sign + y * y * a, -y), dim=1)

    w_world = w[:, 0:1] * b1 + w[:, 1:2] * b2 + w[:, 2:3] * normals
    return w_world

def to_local(d, normals):
    x, y, z = normals[:, 0:1], normals[:, 1:2], normals[:, 2:3]
    sign = torch.where(z >= 0.0, 1.0, -1.0)
    a = -1.0 / (sign + z)
    b = x * y * a

    b1 = torch.concat((1.0 + sign * x * x * a, sign * b, -sign * x), dim=1)
    b2 = torch.concat((b, sign + y * y * a, -y), dim=1)

    w_local = torch.concat((dot(d, b1), dot(d, b2), dot(d, normals)), dim=1)
    return w_local

##
# Ray tracing
def w_to_rays(x, w, spheres_at_x):
    """
    w의 3번째 coordinates가 normal 축이라고 가정
    """
    centers = spheres_at_x[:, :3]  # (N, 3)
    normals = torch.nn.functional.normalize(x - centers, dim=1)
    d = to_world(w, normals)  # (TODO)

    rays = torch.concat((x, d), dim=1)
    return rays

def rays_spheres_intersection(rays, spheres):
    n_rays = len(rays)
    n_spheres = len(spheres)
    x = rays[:, 0:3].unsqueeze(1).expand(n_rays, n_spheres, 3)
    d = rays[:, 3:6].unsqueeze(1).expand(n_rays, n_spheres, 3)
    centers = spheres[:, 0:3].unsqueeze(0).expand(n_rays, n_spheres, 3)
    radii = spheres[:, 3:4].unsqueeze(0).expand(n_rays, n_spheres, 1)

    c_x = centers - x
    c_x_dot_d = dot(c_x, d)
    D = norm(c_x_dot_d * d - c_x)

    intersect = radii > D
    r2_d2 = radii * radii - D * D

    t1 = torch.where(intersect, c_x_dot_d + torch.sqrt(r2_d2), torch.inf)
    t2 = torch.where(intersect, c_x_dot_d - torch.sqrt(r2_d2), torch.inf)

    t = torch.where(t2 > 0, t2, torch.where(t1 > 0, t1, torch.inf))
    min_t, min_indices = torch.min(t, dim=1)

    x_prime = rays[:, 0:3] + rays[:, 3:6] * min_t
    spheres_at_x_prime = spheres[min_indices.squeeze(1)]
    no_hit = (min_t == torch.inf).squeeze(1)
    return x_prime, spheres_at_x_prime, no_hit

# Diffuse BSDF
def eval_cosined_diffuse_bsdf(w_out, w_in, base_color):
    """
    w의 3번째 coordinates가 normal 축이라고 가정
    """
    cos_theta_o = w_out[:, 2:3]
    spec = base_color / torch.pi * cos_theta_o
    return spec

# Monte Carlo integration of reflected radiance
def sample_and_eval_L_r(x, w_out, spheres, spheres_at_x):
    batch_size = len(x)

    w_in = uniform_sample_directions(batch_size)
    w_in[:, 2] = w_in[:, 2].abs()
    rays = w_to_rays(x, w_in, spheres_at_x)

    x_prime, _, no_hit = rays_spheres_intersection(rays, spheres)
    x_prime[no_hit, :] = 0.0

    L_in = scene["caches"](torch.concat((x_prime, -rays[:,3:6]), dim=1))
    L_in[no_hit, :] = scene["env_light"]
    
    f_s = eval_cosined_diffuse_bsdf(w_out, w_in, spheres_at_x[:, 4:7])

    rhs = L_in * f_s * (2 * torch.pi)

    return rhs

##
# Training neural caches
def train(scene, n_iters=100, lr=0.001, batch_size=16):
    caches = scene["caches"]
    spheres = scene["spheres"]
    optimizer = torch.optim.Adam(caches.parameters(), lr=lr)

    for iter in range(n_iters):
        optimizer.zero_grad()

        x, spheres_at_x = uniform_sample_on_spheres(spheres, batch_size)
        w_out = uniform_sample_directions(batch_size)
        w_out[:, 2] = w_out[:, 2].abs()  # uniform hemispherical sampling
        normals = torch.nn.functional.normalize(x - spheres_at_x[:, :3], dim=1)
        lhs = caches(torch.concat((x, to_world(w_out, normals)), dim=1))

        with torch.no_grad():
            rhs = sample_and_eval_L_r(x, w_out, spheres, spheres_at_x)
        
        loss = (((lhs - rhs)**2).sum(dim=-1) / ((lhs.detach()**2).sum(dim=-1) + 0.01)).mean()
        loss.backward()
        optimizer.step()

        if iter % 100 == 0:
            print(f"Iteration {iter}/{n_iters}, Loss: {loss.item()}")
    pass

##
# Rendering
def tone_map(color, limit=1.5, gamma=2.2):
    color = torch.clip(color, 0, None)
    luminance = 0.2126 * color[:,:,0] + 0.7152 * color[:,:,1] + 0.0722 * color[:,:,2]
    result = color / (1.0 + luminance.unsqueeze(2) / limit)
    result = torch.clip(result ** (1 / gamma), 0.0, 1.0)
    return result

def render(scene, width=1024, spp=4):
    camera = scene["camera"]

    loc = camera["loc"]
    lookat = camera["lookat"]
    up = camera["up"]
    fov = camera["fov"]
    focal = camera["focal"]

    # camera basis in world coordinate
    w = (loc - lookat)
    w = w / torch.norm(w)

    u = torch.cross(up, w)
    u = u / torch.norm(u)

    v = torch.cross(w, u)

    # pixel location (i.e., ray's head) in pixel coordinate
    theta = torch.deg2rad(fov / 2.0)
    half_width = torch.tan(theta) * focal

    interval_width = (2 * half_width) / width
    lin = torch.linspace(-half_width + interval_width / 2, half_width - interval_width / 2, width)
    
    y, x = torch.meshgrid(lin, lin)  # plotly convention
    y = -y

    jitter_x = (torch.rand((width, width, spp)) - 0.5) * interval_width
    jitter_y = (torch.rand((width, width, spp)) - 0.5) * interval_width
    
    pixel_x = x.unsqueeze(-1) + jitter_x
    pixel_y = y.unsqueeze(-1) + jitter_y

    pixel_x = pixel_x.reshape(width * width * spp, 1)
    pixel_y = pixel_y.reshape(width * width * spp, 1)

    # pixel location to world coordinate
    w = w.unsqueeze(0)
    u = u.unsqueeze(0)
    v = v.unsqueeze(0)

    d = pixel_x * u + pixel_y * v - focal * w

    # ray construction
    d = d / torch.norm(d, dim=-1, keepdim=True)
    d = d.reshape(-1, 3)

    rays = torch.concat((loc.view(1, 3).expand(len(d), 3), d), dim=1)

    # camera ray tracing
    x_prime, spheres_at_x_prime, no_hit = rays_spheres_intersection(rays, scene["spheres"])
    x_prime[no_hit, :] = 0.0

    # LHS plotting
    color = scene["caches"](torch.concat((x_prime, -rays[:,3:6]), dim=1))
    color[no_hit] = scene["env_light"] 
    color = color.reshape(width, width, spp, 3)
    color = color.mean(2)

    image = tone_map(color).cpu().detach().numpy()
    image = (255.0 * image).astype(np.uint8)
    fig = px.imshow(image, title="Outgoing radiance")
    fig.show()

    # RHS plotting
    normals = torch.nn.functional.normalize(x_prime - spheres_at_x_prime[:, :3], dim=1)
    color_rhs = sample_and_eval_L_r(x_prime, to_local(-rays[:,3:6], normals), scene["spheres"], spheres_at_x_prime)
    color_rhs[no_hit] = scene["env_light"] 
    color_rhs = color_rhs.reshape(width, width, spp, 3)
    color_rhs = color_rhs.mean(2)

    image_rhs = tone_map(color_rhs).cpu().detach().numpy()
    image_rhs = (255.0 * image_rhs).astype(np.uint8)
    fig = px.imshow(image_rhs, title="Emitted radiance + reflected radiance")
    fig.show()

    return color

##
# Neural caches
torch.set_default_device('cuda')
class MLP(torch.nn.Module):
    def __init__(self, input_dim=6, hidden_dim=128, output_dim=3):
        super(MLP, self).__init__()
        self.fc1 = torch.nn.Linear(input_dim, hidden_dim)
        self.relu1 = torch.nn.ReLU()
        self.fc2 = torch.nn.Linear(hidden_dim, hidden_dim)
        self.relu2 = torch.nn.ReLU()
        self.fc3 = torch.nn.Linear(hidden_dim, output_dim)
        self.relu3 = torch.nn.Softplus()
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        x = self.relu3(x)
        return x


##
# Scene definition
scene = {
    "env_light": 3.0,
    "spheres": generate_random_spheres(10),
    "caches": MLP(input_dim=6, output_dim=3),
    "camera": {
        "loc": torch.tensor([5.0, 0.0, 0.0]),
        "lookat": torch.tensor([0.0, 0.0, 0.0]),
        "up": torch.tensor([0.0, 0.0, 1.0]),
        "fov": torch.tensor(60.0), # degree
        "focal":  torch.tensor(0.1)
    }
}

##
# Test runs
_ = render(scene, width=512, spp=16)
train(scene, lr=1e-4, batch_size=2**14, n_iters=3000)
_ = render(scene)
# Out:
# <div>                            <div id="6797f6a9-57a1-4cb7-af0c-a0ac229bae26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6797f6a9-57a1-4cb7-af0c-a0ac229bae26")) {                    Plotly.newPlot(                        "6797f6a9-57a1-4cb7-af0c-a0ac229bae26",                        [{"name":"0","source":"...\u002fWFlEbRVmiNi4SRXNpNptsvB\u002fQC7pQAKqAKqAK+H4O7aMuAIWqAnAvgO5GO67rUuE0m82\u002f\u002fPmH7e0aU+4wr\u002f00DoPGqoNCVxY6QYHIuiMnxk4OzuAQEU1Pnzh7dqZaHWEmAoA4p5AJ4Ouvbq6tvmYKyxD9Ozhr5RSpxKueV8YTOx87g9Mq\u002fP3vPxkZPsxMBABBBUwA\u002f\u002f6v\u002f8MWRUd\u002fCgYYJbRUKoVtAftasXb1SVYTuww7g9Mq+e1nvxgbG2UmAoCIPrbAchsbm2xRbPQnkTlksfEqF+q7FckhN3HHY5vKzuC2Sr777na9vsdMBAARhUoAz56tfv6Xa0whGzi0Sx4EdejpvsaxaPVa4xqClbvkEG1t13744TYzBQBEFCoBXP3+DlPChgztDAr9HY7GcfDifk+vE68ryYIuOUQrq6\u002fn5x80m012KgBEKk4C+Pqrm0yJXECRmzuIjYOmaaWBtN30cOK+X+KVxC7ImcElh+j+wpOlpRfsJACIVJAEsLLyivnYDydSaBQaCk2Tblhi4r4SsS3kzOASEV27fv\u002fRo2fsJAAIV4QEsLGx+e3Xt9jSjGgPiMo5nAgaS7qbSVYiLFi508oB95ADAMQVIQE8e7rKlAQDhBDpxeRiojlkcoB06O+QWEmvZAt2csDW1g47DQB4rE8Ar15tLD546i9JFj5aJBZOGBYNIdDR5KE\u002fA9z2O65DRF9\u002ffXOntstOA4AAuxPAq1cbX35xw1\u002fCjQty4qswOjKKiuqmsg5GrSSSyIL8eVza2q5du3b3AB8KAohjdwK4f+8xW6QEP7R41ERGEwR66cV9xR0MrEVUsgUdcsil1dX1xcUn7DQA6GVxAnj1akPjJ384dakPjjlzOr3U2zXOWCrCrdkrnJ9fxJsBANFsTQCNxj5z+s+NBYrojY95ctz2M3VMJLJNufN4bwj\u002f8U\u002ff4M0AgAi2JoCdnVrweZ+KtUKLufExhZ67PdwYqlbiVSRa0CFqde7Lv17vnQQAXVYmgFptl3nmT6IwEcttnUkWR0\u002fcb3E6\u002f9NL3yq4NTtE5NLWdg3fDAAIY2UCuHH9PlukXjtKOiEBxjKBuO9ndg5ItlTHtev3nj5bYUsBwMYEoPe9XyJ+rFS9jkx0zvcD3QlhZS+JKKTl3kUAEd25\u002fZCZBABkXQJoNpua3\u002fsNj5Wq16STRNBvafdOdy+T1S+yVOg8uBEEEMKyBFCv7+l87zcuaIbGGEPIne+zzO5dsta1lnLp2vV7+N0YAIZlCeBP\u002f\u002fmt\u002f2WyoBBCLG4qXaUi6eK+n9P5n0b66vfV3P1n51+ff3610djvlAOATQng9vwiW6SMTPTUF8DkqIv7fpnkgGRStcqlre3a+voGWw5QYjYlgL29hv9lqnDQlSiGKlp3Inrifrb0jR+35lahS19+hefEAXRZkwBqtd0nS8o\u002fzGdLGO0E\u002fUwaXMSLgM6Cd+489JcDlJk1CWB1Zd3\u002fMnEg8EkXTFW0IE6GQZ+hPwfoq9whCh00l5aWlvGJIACPHQmgVtu9eWOBLU0lJEBI0RfD8or7fqbmgGRLkW\u002fBa9fv+csBSsuOBLC+vul\u002fmTgEtKmJrQ6R45Dj\u002fUPsT4ya5ikg3GLTRDXcJSK6Nf+ALQcoHwsSQLPZvPr9HbY0ofgz69iQHTEplsCyMc3LWveR0QZJ3KTWgi4tLCzh3WAACxLAk6Vl\u002f8vEB79IbA1WzuSD4Ay8oni8quKTUz4CDVVIZ90x8G4wgAUJ4PnzNRVxQmdsTdo8XxrQ2bzUZH5EPiOxLQqboVXu0tLSMr4bDCVnegKo1\u002ffW1l6zpdKEwmtYyBCSfGGjf5KlQ18O0FZxvO9\u002fuM0WAZSJ6Qng5csN\u002f8tEwcLk8NpqW6J+QYywUe1cBKyuri+vvOydCFAipieAe3cfsUVyRKN\u002fWLCQIFcFe8dfbuk8mHYREL6U6EYnop9+2maLAErD6ASwsvJqe7vWeRl+wHOxETYLQk3Mo2GK6MsBmoS1t3MRgN+OhzIzOgG8TH73Xy7ChoWJJGLqimpYzKKG0NPKZLUmW4px4ya+FwYlZXQCWFx8yhYJiQqy+RE68VcS0bQyvoXxg9zDpdXV1\u002fhOAJSTuQmAuTAXvvkgefzrwDZVKPTbhO2g0cIa6y\u002fHdwKgnMxNAEuPX7BFFulGF+nQHxawzOG0\u002flMsWZXJluqB7wRAWRmaAJrNJvP0fzHS0ZaURBAup3An\u002fj6ackBq\u002fAEPa6m\u002ffO3la98rgFIwNAHs7Ow+eSL79H\u002f+wZ+HdugPCzyFobqDqusT5tLt27gLBKVjaAJ4Jf39L6Oifym0NorAttGt3YRUI7+9XXuJiwAoGUMTwPr6T2xRlFRHvjq8ez4GxEd9zMkBscLa2C136dHj574pAMVnYgJoNpv8+z9hB3EK6qoMhP4O+XXIL5E3dS1OWlP4+AtbWlpuNPbZUoDiMjEBSFJw5KfDO\u002fFnJI1q9vAGofOXJZfIVTXA3373N7YIoLhMTAB37\u002f7ofxl5bGcca4KEGxDZDWt5jzJ1iZgOZpYMJOoP2wL+u0Crq+sHzaZvIkCRmZgA6vXwD4CGHcSJpKtMPrqlW59JeoJ7t1v8DkonA341HD0VCi8VzXkt9\u002f4TgMVMTABPuW8AcIgGFA2SrtpRFqgyJx3HefyVpK9KixfLa2wRQEEZlwCePYuL\u002fooCaNJqUoYtIkq+7pzEdznuIiBCMCXErIuIxObhCGud\u002fy7QwsLSxsambyJAYQ2wBXk7cqTqf8k\u002fYh0iN2EISEfdSh2VlWmQb+PcfIenv7+fLQIoIuOuAA4ODtgijrTBgZ9XYqRdKSuyEZET9RE\u002fBw+XU9Mp3Zr9y967\u002f8j3CqCwjEsAd27\u002fyBZxpTnWpaWOiWGcjDvC1Qn6qfqYfz\u002fExLfTpaWlF\u002fgsEJSBcQlAxU\u002fAq5UqLAqJj0mapA36oXLrkRIOEeGzQFAGZiWAptBpVztmZRFl9MTHoCz60qHgfD8DyYYk2VJB+CwQlIFZCUD6i\u002fiJDnexhTIPkdpvB2mP+z3N19sXLbpNdmlhYUl6bwSwjVkJYHe3zhaxNMYvn2zWwqMlbuqN+0W1s1NjiwCKxawEcHAQfQuIF8UUR0wDYqWaHnXO9\u002fPrjpqOqCfYrgeLT9gigGIxKwE87v0ZSMEDVXi+WPnFSoZ0j\u002fzhPs+gzzacfS0n2dLJlgoSu ...
# <div>                            <div id="e1cfd87c-b8e7-4b92-8049-899ea801193b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1cfd87c-b8e7-4b92-8049-899ea801193b")) {                    Plotly.newPlot(                        "e1cfd87c-b8e7-4b92-8049-899ea801193b",                        [{"name":"0","source":"...\u002fGygC4LRPtfZtb9kHg47+a558SJs99ae3\u002frW9\u002fC0+kEXzt47\u002f93\u002f6f\u002fzT\u002f89HvrqzkicsF1bxfnue7s6un85E\u002fe+YAQofjQaqH44aFOZ5HTfvmk8NY\u002fvD5igFcfrOp9i4hcsrYaklypRHrr4zzcvDlyyRABABHBahemChGc8UxQazwiAAACJrMQAA73dTqPXnzn5vK9OROUMnr9yfbyg4W3njJ6\u002fclm\u002fWxGOfHWd7WePsLsLB0647Szxl++v7z+ZMMEVbHYXh\u002fjTOWrePP6qFJZbppsGQOADPn+vrKDy5YxAqTzaHdbzs+z3W1ptAOAMJGUE2ccnMAazzixxquInwCqXTu9+PWPNpfvL\u002fpWU07hdJKRIDR4eHNgnFrtGKcy5s44yqhQ7ATgre9bTRmxxlntKCddNczWad9pqThX7Lhp4HQ6wclo1xy6xWXeVQPlpK16ysniPP\u002fse9eLi\u002fywrWerNCBojSMkqPatHsw4jkLxpuyEZLevtt75OFPXn94bY7NF9E9++3f+jv\u002fCP5nn+duv\u002fBGPeMT\u002f\u002fwh+8gdfC\u002fxf\u002f+yf+uzhkySLnB2jLFSxJIRU+y6gpC37IAj61pSbhgsqFHfGZ7M4CBADHFrj3Sgjns6iKfo3hz6dR6urgglW77pX338oN022iKfo31VDmEhAdNaX21YlQsXicF+35cAFs8YBwuG+BgBEfP\u002fbl4AIgJST5z+znsJ9degQERGG1ljjV08KLunsPL3\u002ffN\u002fX2hofprJv9Pk7cyYoIlx9sLLGteXAJGOcLC4zxok33rtxfpYuLvO+1jLi1b7NV0lXD4DIJUNAxkm96xinMhZMUGc9IkCAMuLz8xQRolTOL9KhM1NWc3YcOoOIq6ticZGHqUxmoQy5igTl5PqTTVv19bFTkRhag4hnz+bOjNkiBkRnfF32u5syKcK+0YjIBVs9KXY3ZZjKctsg4u1nOzPYi3eXTNAkC9uyD0gwunEcTw\u002fXh77RcRqOfhSK68FGiXry\u002flpGYv10MVtlQUD+zsd\u002f9Xf\u002fC7+raZqf\u002fO4f8YhH\u002fKbxNUwA\u002f7Xf\u002fTv\u002f5q\u002f9lSgNAXBxnp9GGFrjzDg\u002fz9MiQsShM0kRYYD1seeCLS7yKJOIGBfh7CxFRDM4LlmUKUS8+nDVHPrrT7Zc0Iv3FioWxTqt9601PkxEnCvKSZQppx2XDBHvPt+fPZshorOeS9Yc+2wRRancXpfOegRkgh7u6+bQOzNyybJ5tH42c9YjYpjIz757kxSRt2NcqDCV2SJCAN2Zat\u002f2je5b4\u002f0YpooJGiaCchqlamgNk9Q7TzlBhNWTAhAZp9s3R29HzmkYi9l5OrQmXUTOjs2xRwQmKBM0SqXprXcjE2x\u002fV52\u002fs7Dah4lwxidFyDgFgJsX274eVCSaY99Vw\u002f6hbsq+WCdDrRHR+zFMRJyHD68Pzrp63+reIGIYi3QWUUaMcYjYN1pGQig2tAYDFJK989G5jITu7f3LfVKE1voAsT72+\u002fsqm8WzdcokHTojFY+zMM7D0wm6aqh27fpqHmDw8Obw\u002fMOrf+73\u002fre3281ProBHPOIRvzl83RLAdrvx9kQIJUGQL5LTCaQSYSy\u002f+Y8\u002fIyRw1p8\u002fWwQk8MafPZtfvbfkkt292veNQQzuPttff7Lhki0uMmfdw+sjl8zbkUs6v0irfVftWkBARESMUsk4DRN5uK8RIcxUlEoEjHMFOG30oVglYSwBMc7D5VXeNxoQEIBLxgRlkiZFWO86JkhSRIe7utq3l+8v3\u002f46ICIOrYlzFecKAbmgiKg7gwjOegDw1t+93E\u002fPlhHXvRMhP26b431d7Tsm2XHbyIg76xEgKULGiTM+jEWchc56Z\u002fyrjx+qfUcZmVLC3ec7DIBymhSR7g3jZHt9XF7mlFPdm6QIj9vWDo5zygRliiEiZeT6k225aZik2Tyen+dTMhta05T93ee7i3cWKhZRJk1vo0wFiE8+WM\u002fWadfoat+GsYyLUPf26r3lcdvEmQpIEOcKg+D1Dx+KReLdKCQTggvJkyJ6+uFZ35l0Fs9WWZSGYRT+wT\u002f2B\u002fu+\u002f4ll8IhHPOI3g69VAvjhD3\u002f4e\u002f6nv7tYZMUyVbGKs1B3Vnemq4e2HIbGyJB\u002f9r3bfBFHmRKKfffvfOrdOFunVrvFRZYvo3rXISITNErVxKQ761UsA8QoU32jrz5Y6d5wyfpa7+\u002frat8CoIpEkqu+0VQQLli5ac\u002femYexnOLv0JrjtnHO28GlRQiIVjtnPAIg4uw8lSE\u002f3FciZFEqnfOvvv\u002fg7IgIznhr\u002fHHTttVAOWGCFsuYctrXOptHu5uq3nfZPEKAvtbejowR70ZnfDqPolR25XD2fK47yzgFREB0dkxmobP+uG0Yp0xQoZjV7v7V4eHVsa81EwxO6K33zqtIHO7rdBFvb8rm2COgd2OxjItVIiNR7br1k1kYC+\u002fGs+cza1yShd55QAhjGSaiWKdtNUSZqg89IqpIykggorW+3DbHXROnqq\u002f13ee7bBZ7N3a1DoLAWR8gcsmrXZvOot195f14\u002f3o\u002fjuPrT+5P44lQMrpRhWJ5MYuT8OkHFy\u002fufvBn\u002fvyf\u002fsml8IhHPOI3Afw6FYH\u002fK\u002f\u002fMPxEnyfJyJpQ4jZDP46GzdvBWuyhT+SKx2i0uci5ZuWtn61RIVu07DNBqN1ulznlnPCIa7eJcOe0xwPl5hgh3nx\u002fiXCHC\u002fq5OZqHVbnmZO+ud9fu7ev1shggyFN75odVJEe3vqmwR9Y0BhKQI71\u002fuL99fbt4cuaCA2JY9lyxM5bQlj3LVlr2MxP6uyuZR3+iJX4oypXuLAH2j5+dZVw\u002fVvmWCAYDVbnmVHzcNAlBOoly1xx4Aulqn8wjgNDRmKg63Vd\u002fXOpmFlJGhNV2tAU6zdVofOsbpCeH4UOdflJGd9X2r80UMAMdNcwJQEbfGx5k8bBoV8etPtqunxXFTLy6yvtYyFs64w0Nz+f6CS2YG++ZHD2fP5s66cttSQdpjny1jq90JTpSROFX7hxpOJ8rICU5tNaSzkFASkMBZ1zc6SuU4nu5f72ar9LhtTqdTvoirfcMV6+rB+\u002fH28002j958+vD0g\u002fXdyy1 ...
# Iteration 0/3000, Loss: 1.292201280593872
# Iteration 100/3000, Loss: 0.9665079116821289
# Iteration 200/3000, Loss: 0.9099463224411011
# Iteration 300/3000, Loss: 0.9453305006027222
# Iteration 400/3000, Loss: 1.0878119468688965
# Iteration 500/3000, Loss: 1.1914409399032593
# Iteration 600/3000, Loss: 1.2285919189453125
# Iteration 700/3000, Loss: 1.2435500621795654
# Iteration 800/3000, Loss: 1.2930560111999512
# Iteration 900/3000, Loss: 1.3128411769866943
# Iteration 1000/3000, Loss: 1.2749030590057373
# Iteration 1100/3000, Loss: 1.3460972309112549
# Iteration 1200/3000, Loss: 1.4152617454528809
# Iteration 1300/3000, Loss: 1.3463869094848633
# Iteration 1400/3000, Loss: 1.2506160736083984
# Iteration 1500/3000, Loss: 1.25923490524292
# Iteration 1600/3000, Loss: 1.2645939588546753
# Iteration 1700/3000, Loss: 1.3405787944793701
# Iteration 1800/3000, Loss: 1.2420933246612549
# Iteration 1900/3000, Loss: 1.1930444240570068
# Iteration 2000/3000, Loss: 1.327399492263794
# Iteration 2100/3000, Loss: 1.2790014743804932
# Iteration 2200/3000, Loss: 1.3077861070632935
# Iteration 2300/3000, Loss: 1.224303960800171
# Iteration 2400/3000, Loss: 1.244364857673645
# Iteration 2500/3000, Loss: 1.2580597400665283
# Iteration 2600/3000, Loss: 1.2043834924697876
# Iteration 2700/3000, Loss: 1.146119475364685
# Iteration 2800/3000, Loss: 1.191648006439209
# Iteration 2900/3000, Loss: 1.2271943092346191
# <div>                            <div id="fe26dab5-8524-457b-a3c9-19c10a61a86d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe26dab5-8524-457b-a3c9-19c10a61a86d")) {                    Plotly.newPlot(                        "fe26dab5-8524-457b-a3c9-19c10a61a86d",                        [{"name":"0","source":"...\u002fKQi20F+3bNkFFbAljGVkdZufBGEu7O6+UEOl1GVxDufG\u002fe03F8\u002f4f98519rfOaf7+06\u002fz95rznc84xljvHOutfY75lpr7y1jDGy8Pfjyf\u002f+l\u002f9fP\u002fbHjOG6343a73W7HcTuO4xAR3eqtwAkAcoggmTYUkOYgvkzF+s3ipu5Cp8NqNqHv1ZPMgBcMZjFSuxPEOrPoLazASh+Yp3SGO7pyMgL6tKy7jJHJMTPDaLWNCzpLqtszTZI0jORF5WMXnQ08ogySSKfBQYqJYd6U8by1LCVbCnWF0gzRjYrpimEeP+fxeB7j+XmM5zHGeH71PMZ49Wq8+trz86vn5+fnP\u002fh\u002f+bexsbGxsbHxjYOMMTq38abiL\u002f9XP\u002fMz\u002f+1\u002feLsdT+88HbfjdrsdIukCQHgVAHBcAe\u002f1BYIjCPaypGV9DQBtlbnRbtUZANpem5UUySSVhXVfPOZY9dk1\u002fYpw9EKOFDL5cMGtJnmGK1mfmGvj+VhHi+fp8E3s6\u002fO5PL3Z7MbYzFQnya1NRlXlBJ224BSqKUeWLAYL1pPYsBDwzHnLUY6fvsYoRkrggWOoCxjPz5SoUpGGbcyO\u002f1nt51cDGK9ejfH8\u002fPw8np\u002fH89een5+f\u002f87fefX7\u002f4kf\u002fOQnPoWNjY2NjY1vBI5ObLyp+Mv\u002f5c\u002f8pb\u002fxHxyH3J6eDkLE9gEsun+2uWYAAjEb0DHsyweuZHeq3b\u002fOxi8M1Jt2yZQUAehETJj2okZoAUDn15Dy+rcnqOiFOAyt5qiYOAFE5x4zvYNTWanPfdPGOBwCCM93ySpAOXcC6pLC7n1VWBpPzMyGqvaxRWgCdcetSSyUYzHLBjEBEZSHoLOWQotRpuLghWGMEQ30YcqSvyyPRUUCmyAHQdNnmkQRSBxEAMFxyHGIQI6biMhx8Hkqx02Op+O4He+8c\u002fvCL\u002f4CNjY2NjY2vkHYFwBvB957\u002f93\u002f+Bf\u002fwtM7T7enW\u002fT3tdH3hgbsfABoU2SCZEBAidOpMdJwMUHZmBZE0ntO3yXTgsNDYwp1fbKDBTMVXxdaYh8WihI96g7jXJ9OVI4\u002fQS+TqeQQrd+1hsKXUIHGJQhQ7g7ek9kftmbye1KpdDqkJPOxnXSL1nFJpElEQz26DsQL6pHoA9IG5mYQGaZVjxankIXDo9vIZpn0yzixZ0\u002fKqg6VMY3FU8uRuY3ljukO\u002fSSeMwCOQ+QQOeTQiwG5PR1\u002f7ud\u002f5L3338XGxsbGxsY3AvsjQG8B3nv\u002f3R\u002f66e8\u002fbvLOt7wjIvzov4gct9tx8EP\u002f2nNMr\u002f0brB\u002fSLscbIeXZAqlr8eU9lW84M\u002fPaOHmMJpNMUlnrextG0sAiSwlcUKWGk51QdHGf8B0UQVeH3T0Zws+wNHQq2aM5J9s+FuN2GPzYS4ybu4nLGBqtt9m0iegmWfYhmyRK2TkoupSCwyRJQmD04POtpRth0Os3uhiRHOSflR3P5uHgeQD2ESCKbcTfARgDz6+en8d4fvXMzwi9+trzq689f+\u002f\u002f8Q\u002ftzwJtbGxsbHydsd8BeAvwX\u002fzNL8ghT09Pws\u002f4HyLHcdy02deeXryJN9AAOAiFagBVQ1xCJ\u002ff+BTbN3MA2FqHj5BFvslncTSWtoNm+pyeSOjjLTtesXs2JapPqOQjWTBMqeeb5FKjAJ9ANjb7K40e9EC1so\u002foh9pMnAr2fzY4zIObXsblNy8jkiTE4CduH6SqdiAACnQMtpWn7VCyOjOos1gYcemLTaASEWSK4bymg4fMwGE2ZuqADj\u002fEQQOC\u002fTG+DQwDIoRK++i\u002fEcRy3g14jdHt7Or7wX+\u002fPAm1sbGxsfL3x1ImNNwx\u002f+b\u002f6mb\u002f0N\\u002f0L\u002fwIBP\u002fgd\u002fxD2NjY2NjY+HphXwC86fiP\u002f+u\\u002f7+R8B9jXAxsbGxsbXD\u002fsjQG8u3nv\u002f3f\u002f0\u002f\u002fMzT+\u002fY3\u002fqU47jpy\u002f+AiPC1f46EJLhlHwLulRfRHV0CjQDosiB1W3zK5iP3WX5oEe7oDJGFFKeO6p4KTtQ9AaPFsydXSl+pxHeVnYGOxHlIVF5FdFxpIp8dTnfHSA0NmcWKMimLqVJJosjqRUSgjwy67HGiFoU2tokIIMJ7I1NkqQ5FzEBgD8dIauEeGDVNKfAgGpSImNgTlI3V0mBPQl6WWd3JKE4owhijN5stPbqnPNRiH95z93GT43ZQd3s6fvqv\u002fftf\u002fsoXsbGxsbGx8XWBvva28Qbie\u002f\u002f07\u002f6WX\u002fUtx+14errxwz\u002f8k\u002f\u002f2AeJD+BvAV7AWJP79VzQx3p+kLopW+tJGSkecmI\u002fVdpG5bZz1y6EiIrrhaPUCC+5usjKPjnWI+OYOFppOpXN1hfLEnIz101Zf5TdjkqrfmAH4OwW2Kz8Q2o8Hvvyv48XNJKHIFSOab0csKnLsTIpKITbwfBbV1Imchro15aBbB86oM0gbJ7ipmmePIun\u002fE4A3+0cB\u002fD3g5+fn8Wo88xeCXz3\u002fM7\u002fx9\u002f ...
# <div>                            <div id="f3b0d02e-c3a2-44fe-a1e7-db81ddb585e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3b0d02e-c3a2-44fe-a1e7-db81ddb585e4")) {                    Plotly.newPlot(                        "f3b0d02e-c3a2-44fe-a1e7-db81ddb585e4",                        [{"name":"0","source":"...\u002fF\u002fXvbKBAIklFwjWrnblBgmWsU2xTUmlht57771327gANr333juETki+SWiGBNsgkYCbtE2EuEgigQSwtff7h3Ke887vr98573me53tm9JlhhmEYe7W72tnrvsqNlFLw+7+HKIkpnVrUeb8OUIhr1jSwdgDDMLpaTN7tnweN6u10vPjXt7fbd\u002fkUKdy4+kPnrp+booyhDYMJQ7IXre\u002fao\u002f2lszd7Ders+1FMIEOrKR\u002fDggZSmdq8TVzhgyeEQVpD+ShWLFUD6jDUSxOSLPWD6s2dsuxVxV+DRvXiI9kt6\u002fZ0694JAALqMEf2nlucOV0SVT6ClcpUPpKlGiABqUy9dPF6zz5dWN6ICGKpgoB8FAsaAIHsBetSV83ZtHZn925d+Gh2795DCxbPTJ2\u002fkiGEBJKp08YBBUeR3PyTuIe3rUwtYhKMwaH6Rw+feN9pjA691dTcmPN9CkeR4vuLEMM5imVzDEcCMGPO2g37svLvWQlDgMKF85dnzJkolSmUAiK065T8w+U8oTEHAMEN9EDBVe5GglxE+KRBcxZlz0YCK9M3LEyfuTpjY9\\u002fmpFLFFGHMmJ+zcX8upQAIBXetVKNHDp4YOWFwzRstsa2lXv26ACCVqoBgCNXXq18XgP54LQ8o8NGsIUxf9bsbEWSHWv23l+iQj2INofrH+baaNxrR4bG9pxZmz6ZesD+TzI05SkGRVe87LSHFUv+Dej9cvfv1hYs9enZHBM7MLl+yZu3u5VW\u002fu4Ib6Kt+dzmKleMHTi\u002fKnk2Rrl22qc+QXnwUK5UqLG8kOtC8VLYrmpfu33TMYKw\u002fbe4kR7HMmY1IwBTJ\u002fnj1XkLr2IrfXOuyt\u002fTu352LNAaH6gGh3vt1v7989\u002fC2k0Mn9gcCVKNGvpHjmUICsFmrjyvLXVoNVeyqBvT6hZtvXr2btHC0WKQYhQ\u002fFEuXbK98PHTdAdjhr3tV4a7Tqd9V8FFvxm0uxP\u002f\u002fh63u+m9bPz8\u002fPz++\u002fBfn\u002f\u002fQe\u002ff2M3b95M7tDiy86fNP2oicXyke2XX2xPfiEMgRp4L6j2c\u002fX3b6\u002ffHjNlcHyrpnwM+1792kIMRwiTm7658J7tq27tmQCm54BOAJCQbDE34cALpijjjvUHtm84cPHs9fQ5q4DCd9\u002f9+FnX1rLdSRhkuXBThLHgvk0sUabNGjt4dG9CMCdtc\u002f3QukwAYQIIyxvr6es4ihUADGloIAxSCiEfGmTRyUezyOB3t3\u002fcsmGPVKYixSN7zgACIIjFyojJAxxF8ox5E4RoDhHFx789vPW4T79uPXt\\u002fqj9eZGxcvnZ2ZNmPFuBnDh4wbsGP9gYQUy+BPJt66kcfxLKUwd3IqZ2KBAVel59Wfr+dMXEK9UPNOC26g91ZrSGDstBHNWsUGN9RPmjcKNLxw9oKr3J2YYgEAzsxq74AzGz\u002f5KnnZjJWypIIXevbqLhbJQgwHXrj6zVVOYMfPGgkAuTszC+5ag0P0JjP7W5lLsitAQSyW45NiVdWZvnpRvffruircrnI3E4AAMHTEwL0bDn\u002fyVQpQuHUzT3E4EcEQop\u002fQe\u002farP1+\\u002fTrt23JYV4tR7M5vr37\u002fRafP9m44YoowskIjLjLcFGV8r\u002f57Lz0vm7eL6zzo81evXv3PL7afn5+fn99\u002fLfRnAP5vcfPmzZEzhsY0jqofVNdo\u002fvDsoStDJ\u002fZlCAmoE\u002fBcekEYAhogIqMjfDT7XH1x\u002feL3nbp+hgxBgLNHr85JnxD6YXDh\u002fSeXz3\u002fTtUcHRPzm5g+dOn+OiIgoNGalMlV7R4kOETDv0U8pCa10tRnqpZ90Spk+Yknvfl8JjTmxSCE6pBqcOHR+0MjeQgwbHGao+t0NAKEfGh7etgoxbG7qptW7lhXk2YACH8WKpQoyqL2j5sYcEpTsytkTl2q83gGDeyW2tixblDtt1nixWCEMHjl4ZvCQPsigOYYDBuQyp\u002fethgQAkAQgInCCkXoBABTJyQnG4Ab62eNTl2bPXrNiy9xFUx3FChOIJoF1lMjmxtx\u002frH8LH3H0HRVLlMQ2cQAwfcSi0dMGa2\u002fpwf0nR40fGN8qtqrcjQzKZSoFShj0vqUJrS0F96xEhxfOXVq7bTkAvPrz9aOfnnjfaYTB+JRYoPjw1uOIJpxYpjABxJLY1F3psT+ThBhOcagAwAlGSkEqU\u002fhojjOHy2VOoLBx3bYZcyZLZYopgl2dvYEQpk\u002ffHnwU5yiSmUDSpn2rW9fy+CjOUSILMdzCcRk5u9KBAhDgzOG3ruUBIiHQLCn20U82qsG+LYcz1i3esXNX165fnTx8rnevHqjD08fO9BvUh+iwWcvYgjzr5cuXu3Xvdmjr0 ...
